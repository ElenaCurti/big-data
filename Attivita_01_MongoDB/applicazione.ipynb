# %% [markdown]
# # Applicazione Python "Premi Nobel"
#
# Attività scelta: 3. MongoDB Usecase e applicazione Python <br>
# Progetto realizzato da Elena Curti con Python 3.9.13.
#
# Ho usato i seguenti file JSON pubblici: <br>
#     <ul>
#       <li> nobelPrizes.json: https://masterdataapi.nobelprize.org/2.1/nobelPrizes?offset=0&limit=664 </li>
#       <li> laureates.json: https://masterdataapi.nobelprize.org/2.1/laureates?offset=0&limit=981 </li>
#     </ul>
# Essi contengono informazioni sui premi Nobel ed i relativi vincitori.
#
# ## Documentazione
# Documentazione dei dataset: https://app.swaggerhub.com/apis/NobelMedia/NobelMasterData/2.1

# %% [markdown]
# ## File con i premi Nobel
# Il file <i>JSON_Files/modificati/nobelPrizes2.json</i> contiene l'elenco dei premi Nobel, con la seguente struttura d'esempio:

# %% [markdown]
# ```
# {
#     "awardYear": 2021,
#     "category": "Economic Sciences",
#     "categoryFullName": "The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel",
#     "dateAwarded": "2021-10-11",
#     "topMotivation": "for contributions ...",
#     "prizeAmount": 10000000,
#     "laureates": [
#         {
#             "id": "1007",
#             "knownName": "David Card", // Solo per le persone
#             "orgName": "Institute of International Law", // Solo per le organizzazioni
#             "portion": "1/2",
#             "sortOrder": "1",
#             "motivation": "for his empirical contributions to labour economics"
#         },
#         { ... }
#     ]
# }
# ```

# %% [markdown]
# ### Modifiche effettuate
# Rispetto al file JSON originale (contenuto in <i>JSON_Files/originali/nobelPrizes.json</i>):
# <ul>
#     <li> Ho rimosso i sottoalberi "/link" e "/meta" perchè contenenti informazioni non inerenti ai premi Nobel. <br></li>
#     <li>
#         Ho rimosso la traduzione di alcuni campi. La struttura originale di tali campi era la seguente:

# %% [markdown]
# ```
# "nome": {
#     "en": "termine_inglese",
#     "no": "termine_svedese",
#     "se": "termine_norvegese"
# }
#
# ```

# %% [markdown]
# <ul>
# <li style="list-style-type: none; ">
#     Ho deciso di lasciare solo il termine inglese, trasformando quindi i campi in formato testuale. <br>
#     Ho eseguito questa modifica per i campi: "category", "categoryFullName", "laureates.knownName" e "laureates.motivation".
# </li>
# <li> Ho trasformato "awardYear" in un campo intero (originariamente testuale)</li>
# </ul>

# %% [markdown]
# ## File con i vincitori
# Per arricchire il database, ho deciso di inserire anche il file <i>JSON_Files/modificati/laureates2.json</i> che contiene l'elenco dei vincitori dei premi Nobel, con la seguente struttura d'esempio:

# %% [markdown]
# ```
# // Per le persone
# {
#     "id": "102",
#     "knownName": "Aage N. Bohr",
#     "givenName": "Aage N.",
#     "familyName": "Bohr",
#     "fullName": "Aage Niels Bohr",
#     "gender": "male",
#     "birth": {
#         "date": "1922-06-19",
#         "place": {
#             "cityNow": "Copenhagen",
#             "countryNow": "Denmark"
#         }
#     },
#     "death": {
#         "date": "2009-09-08",
#         "place": {
#             "cityNow": "Copenhagen",
#             "countryNow": "Denmark"
#         }
#     },
#     "wikipedia": "https://en.wikipedia.org/wiki/Aage_Bohr"
# }
#
# // Per le organizzazioni
# {
#     "id": "537",
#     "orgName": "Amnesty International",
#     "nativeName": "Amnesty International",
#     "founded": {
#         "date": "1961-00-00",
#         "place": {
#             "cityNow": "London",
#             "countryNow": "United Kingdom"
#         }
#     },
#     "wikipedia": "https://en.wikipedia.org/wiki/Amnesty_International"
# }
# ```

# %% [markdown]
# ### Modifiche effettuate
# Rispetto al file JSON originale (contenuto in <i>JSON_Files/originali/laureates.json</i>):
# <ul>
#     <li>
#         Ho rimosso i sottoalberi "/link" e "/meta" perchè contenenti informazioni non inerenti ai vincitori.
#     </li>
#     <li>
#         Come prima, ho rimosso la traduzione svedese e norvegese (lasciando solo quella inglese) dei seguenti campi: "knownName", "givenName", "givenName", "fullName", "cityNow", "countryNow", "orgName"
#     </li>
#     <li>
#         Ho modificato i campi "birth.place", "death.place" e "founded.place" rimuovendone i sotto-campi "city", "country", "continent" e "locationString". In questo modo ho semplificato la struttura del file, rimuovendo informazioni molto specifiche sui luoghi geografici e non inerenti al vincitore del premio.
#     </li>
#     <li> Ho rimosso il campo "nobelPrizes", contenente l'elenco dei premi Nobel vinti dalla persona/organizzazione, perchè già memorizzati nel file nobelPrizes2.json.
# </ul>

# %% [markdown]
# ## Struttura delle Collection
# Nelle interrogazioni proposte nell'applicazione, ho dato la possibilità all'utente di scegliere se visionare i vincitori dei premi in modo sintetico (solo il nome) o dettagliato (tutti i campi). Quindi, ho deciso di non unire i file laureates2.json e nobelPrizes2.json, e di tenere due collections distinte.

# %% [markdown]
# ## Applicazione
# Eseguire il codice nelle celle, seguendo l'ordine proposto. <br>

# %% [markdown]
# ### Operazioni iniziali e definizione di funzioni

# %% [markdown]
# Il seguente codice crea ed inizializza un database chiamato <i>premi_nobel</i>, formato dalle due collections <i>laureates2</i> e <i>nobelPrizes2</i> (contenenti i dati memorizzati nei relativi file JSON). <br>
# <b>NB: Eseguedo questo codice, gli eventuali dati memorizzati nelle collections e non presenti nei file JSON saranno eliminati. </b> Eseguire quindi il codice nel primo avvio dell'applicazione o quando si vuole ripristinare il database.

# %%
import json, sys, os
from pymongo import MongoClient

class MiaStopExecution(Exception):
    """Il raise di questa classe provoca l'interruzione dell'esecizione della cella, senza interrompere il kernel"""
    def _render_traceback_(self):
        pass

def carica_dati(nomeFile, collection):
    ''' Funzione che carica il file json nella collection. '''
    collection.drop()
    try:
        with open(path_cartella_file_json+nomeFile, encoding='utf8') as file:
            file_data = json.load(file)
    except FileNotFoundError:
        print("Path inserito non valido! Assicurarsi di aver messo / o \\\\ alla fine del path.", file=sys.stderr)
        raise MiaStopExecution
    collection.insert_many(file_data) 

# Costanti
FILE_LAUREATES = "laureates2.json"
FILE_NOBEL_PRICES = "nobelPrizes2.json"
LOOKUP_JOIN_COLLECTIONS = { 
            '$lookup': { 
                "localField": "laureates.id",
                "from": "laureates2",
                "foreignField": "id", 
                "as": "laureates" 
            } 
        }

# Inizializzazione del database
myclient = MongoClient("mongodb://localhost:27017/")
db = myclient["premi_nobel"]
collection_laureates2 = db["laureates2"]
collection_nobelPrices2 = db["nobelPrizes2"]

path_cartella_file_json =  "JSON_Files" + os.sep + "modificati" + os.sep

carica_dati(FILE_LAUREATES, collection_laureates2) 
carica_dati(FILE_NOBEL_PRICES, collection_nobelPrices2)
print("Database inizializzato correttamente")
# Out:
# Database inizializzato correttamente

# %%
def get_info_event(dizionario):
    """Funzione che ritorna l'evento in input serializzato in una stringa"""
    ret_str = ""
    if "date" in dizionario:
        ret_str += dizionario["date"]
    if "place" in dizionario:
        ret_str += " a "+ dizionario["place"].get("cityNow", "") + ", " +dizionario["place"].get("countryNow", "")
    return ret_str


def print_vincitore(l, stampa_dettagli):
    """Funzione che stampa i dati del vincitore in input"""
    if "knownName" in l:
        print("Persona: " + str(l["knownName"]))
    if "orgName" in l:
        print("Organizzazione: " + str(l["orgName"]))

    if not stampa_dettagli:
        return
    # Dettagli persone
    if "givenName" in l or "familyName" in l or "fullName" in l:
        print("\tAltri nomi: " + str(l.get("fullName", '')) + " - " + str(l.get("givenName", '')) +" - " + str(l.get("familyName", '')))
    if "gender" in l:
        print("\tSesso: " + str(l["gender"])[0])
    if "birth" in l:
        print("\tNato/a il " + get_info_event(l["birth"]))
    if "death" in l:
        print("\tMorto/a il " + get_info_event(l["death"]))
    
    # Dettagli organizzazioni
    if "nativeName" in l:
        print("\tAltri nomi: " + str(l["nativeName"]))
    if "founded" in l:
        print("\tFondato/a il " + get_info_event(l["founded"]))
    
    # Dettagli comuni
    if "wikipedia" in l:
        print("\tWikipedia: " + str(l["wikipedia"]))

def print_nobels(nobel_list, stampa_dettagli):
    """Funzione che stampa il nobel dato in input (in modo dettagliato se stampa_dettagli e' true)."""
    
    def print_nobel(nobel):
        print("Anno: " + str(nobel.get('awardYear', "-")))
        print("Categoria: " + str(nobel.get('category', "-")) + " - anche detta " + str(nobel.get('categoryFullName', "")))
        print("Data: " + str(nobel.get('dateAwarded', "-")))
        print("Motivazione: " + str(nobel.get('topMotivation', "-")))
        if "prizeAmount" in nobel:
            prizeAmount = nobel['prizeAmount']
            print("Importo del premio (in corone svedesi): " + get_importo(prizeAmount))
        laureates = nobel.get('laureates', [])
        for l in laureates:
            print_vincitore(l, stampa_dettagli)
            if 'portion' in l:
                print("\tPorzione del Nobel vinta: " +  str(l['portion']))
            if 'motivation' in l:
                print("\tMotivazione: " +  str(l['motivation']))

    
    for nobel in nobel_list:
        print("*************")
        print_nobel(nobel)

def chiedi_stampa_dettagli():
    return input("Stampare anche i dettagli dei vincitori (y/n)?").lower()=='y'

def get_importo(importo):
    return str(f"{importo:,.2f}")

def chiedi_categoria():
    print("Scegli una categoria tra: ")
    lista_categorie = collection_nobelPrices2.distinct("category") 
    i = 0
    for cat in lista_categorie:
        print(str(i)+ " -- " + cat)
        i+=1
    try:
        num_categoria = int(input(">> "))
        if num_categoria <0 or num_categoria >= len(lista_categorie):
            print("Valore non valido!")
            raise MiaStopExecution
        
        scelta = lista_categorie[num_categoria]

    except ValueError:
        print("Valore non valido!")
        raise MiaStopExecution
    return scelta

# %% [markdown]
# ### Interrogazioni

# %% [markdown]
# #### 1. Cercare tutti i vincitori dei premi Nobel di una categoria

# %%
print("Cercare tutti i vincitori dei premi Nobel di una categoria")

# Stampa del menu e richiesta degli input
print("Quale categoria? ")
categoria = chiedi_categoria()

stampa_dettagli = input("Stampare anche i dettagli dei vincitori (y/n)?").lower()=='y'
print("Scelta: " +  categoria+ " "+("con" if stampa_dettagli else "senza" ) + " dettagli")

# Interrogazione e stampa dei risultati
if stampa_dettagli:
    lista_nobel = collection_nobelPrices2.aggregate([
        {'$match': {"category":categoria}}, 
        LOOKUP_JOIN_COLLECTIONS
    ])
else:
    lista_nobel = collection_nobelPrices2.find({"category":categoria}) 

print_nobels(lista_nobel, stampa_dettagli)
# Out:
# Cercare tutti i vincitori dei premi Nobel di una categoria
# Quale categoria?
# Scegli una categoria tra:
# 0 -- Chemistry
# 1 -- Economic Sciences
# 2 -- Literature
# 3 -- Peace
# 4 -- Physics
# 5 -- Physiology or Medicine
# >> 3
# Stampare anche i dettagli dei vincitori (y/n)?n
# Scelta: Peace senza dettagli
# *************
# Anno: 1901
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1901-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 150,782.00
# Persona: Henry Dunant
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his humanitarian efforts to help wounded soldiers and create international understanding
# Persona: Frédéric Passy
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his lifelong work for international peace conferences, diplomacy and arbitration
# *************
# Anno: 1902
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1902-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 141,847.00
# Persona: Élie Ducommun
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his untiring and skilful directorship of the Bern Peace Bureau
# Persona: Albert Gobat
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his eminently practical administration of the Inter-Parliamentary Union
# *************
# Anno: 1903
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1903-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 141,358.00
# Persona: Randal Cremer
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his longstanding and devoted effort in favour of the ideas of peace and arbitration
# *************
# Anno: 1904
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1904-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 140,859.00
# Organizzazione: Institute of International Law
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for its striving in public law to develop peaceful ties between nations and to make the laws of war more humane
# *************
# Anno: 1905
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1905-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 138,089.00
# Persona: Bertha von Suttner
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for her audacity to oppose the horrors of war
# *************
# Anno: 1906
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1906-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 138,536.00
# Persona: Theodore Roosevelt
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his role in bringing to an end the bloody war recently waged between two of the world's great powers, Japan and Russia
# *************
# Anno: 1907
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1907-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 138,796.00
# Persona: Ernesto Teodoro Moneta
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his work in the press and in peace meetings, both public and private, for an understanding between France and Italy
# Persona: Louis Renault
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his decisive influence upon the conduct and outcome of the Hague and Geneva Conferences
# *************
# Anno: 1908
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1908-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 139,800.00
# Persona: Klas Pontus Arnoldson
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their long time work for the cause of peace as politicians, peace society leaders, orators and authors
# Persona: Fredrik Bajer
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their long time work for the cause of peace as politicians, peace society leaders, orators and authors
# *************
# Anno: 1909
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1909-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 139,800.00
# Persona: Auguste Beernaert
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their prominent position in the international movement for peace and arbitration
# Persona: Paul Henri d'Estournelles de Constant
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their prominent position in the international movement for peace and arbitration
# *************
# Anno: 1910
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1910-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 140,703.00
# Organizzazione: Permanent International Peace Bureau
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for acting as a link between the peace societies of the various countries, and helping them to organize the world rallies of the international peace movement
# *************
# Anno: 1911
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1911-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 140,695.00
# Persona: Tobias Asser
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his role as co-founder of the Institut de droit international, initiator of the Conferences on International Private Law (Conférences de Droit international privé) at the Hague, and pioneer in the field of international legal relations
# Persona: Alfred Fried
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his effort to expose and fight what he considers to be the main cause of war, namely, the anarchy in international relations
# *************
# Anno: 1912
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1913-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 140,476.00
# Persona: Elihu Root
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for bringing about better understanding between the countries of North and South America and initiating important arbitration agreements between the United States and other countries
# *************
# Anno: 1913
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1913-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 143,010.00
# Persona: Henri La Fontaine
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his unparalleled contribution to the organization of peaceful internationalism
# *************
# Anno: 1914
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 146,900.00
# *************
# Anno: 1915
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 149,223.00
# *************
# Anno: 1916
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 131,793.00
# *************
# Anno: 1917
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1917-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 133,823.00
# Organizzazione: International Committee of the Red Cross
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for the efforts to take care of wounded soldiers and prisoners of war and their families
# *************
# Anno: 1918
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 138,198.00
# *************
# Anno: 1919
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1920-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 133,127.00
# Persona: Woodrow Wilson
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his role as founder of the League of Nations
# *************
# Anno: 1920
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1920-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 134,100.00
# Persona: Léon Bourgeois
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his longstanding contribution to the cause of peace and justice and his prominent role in the establishment of the League of Nations
# *************
# Anno: 1921
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1921-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 121,573.00
# Persona: Hjalmar Branting
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their lifelong contributions to the cause of peace and organized internationalism
# Persona: Christian Lange
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their lifelong contributions to the cause of peace and organized internationalism
# *************
# Anno: 1922
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1922-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 122,483.00
# Persona: Fridtjof Nansen
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his leading role in the repatriation of prisoners of war, in international relief work and as the League of Nations' High Commissioner for refugees
# *************
# Anno: 1923
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 114,935.00
# *************
# Anno: 1924
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 116,719.00
# *************
# Anno: 1925
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1926-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 118,165.00
# Persona: Sir Austen Chamberlain
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his crucial role in bringing about the Locarno Treaty
# Persona: Charles G. Dawes
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his crucial role in bringing about the Dawes Plan
# *************
# Anno: 1926
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1926-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 116,960.00
# Persona: Aristide Briand
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their crucial role in bringing about the Locarno Treaty
# Persona: Gustav Stresemann
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their crucial role in bringing about the Locarno Treaty
# *************
# Anno: 1927
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1927-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 126,501.00
# Persona: Ferdinand Buisson
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their contribution to the emergence in France and Germany of a public opinion which favours peaceful international cooperation
# Persona: Ludwig Quidde
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their contribution to the emergence in France and Germany of a public opinion which favours peaceful international cooperation
# *************
# Anno: 1928
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 156,939.00
# *************
# Anno: 1929
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1930-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 172,760.00
# Persona: Frank B. Kellogg
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his crucial role in bringing about the Briand-Kellogg Pact
# *************
# Anno: 1930
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1930-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 172,947.00
# Persona: Nathan Söderblom
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for promoting Christian unity and helping create 'that new attitude of mind which is necessary if peace between nations is to become reality'
# *************
# Anno: 1931
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1931-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 173,206.00
# Persona: Jane Addams
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their assiduous effort to revive the ideal of peace and to rekindle the spirit of peace in their own nation and in the whole of mankind
# Persona: Nicholas Murray Butler
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their assiduous effort to revive the ideal of peace and to rekindle the spirit of peace in their own nation and in the whole of mankind
# *************
# Anno: 1932
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 171,753.00
# *************
# Anno: 1933
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1934-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 170,332.00
# Persona: Sir Norman Angell
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for having exposed by his pen the illusion of war and presented a convincing plea for international cooperation and peace
# *************
# Anno: 1934
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1934-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 162,608.00
# Persona: Arthur Henderson
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his untiring struggle and his courageous efforts as Chairman of the League of Nations Disarmament Conference 1931-34
# *************
# Anno: 1935
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1936-11-24
# Motivazione: -
# Importo del premio (in corone svedesi): 159,917.00
# Persona: Carl von Ossietzky
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his burning love for freedom of thought and expression and his valuable contribution to the cause of peace
# *************
# Anno: 1936
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1936-11-24
# Motivazione: -
# Importo del premio (in corone svedesi): 159,850.00
# Persona: Carlos Saavedra Lamas
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his role as father of the Argentine Antiwar Pact of 1933, which he also used as a means to mediate peace between Paraguay and Bolivia in 1935
# *************
# Anno: 1937
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1937-11-18
# Motivazione: -
# Importo del premio (in corone svedesi): 158,463.00
# Persona: Robert Cecil, Viscount Cecil of Chelwood
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his tireless effort in support of the League of Nations, disarmament and peace
# *************
# Anno: 1938
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1938-11-17
# Motivazione: -
# Importo del premio (in corone svedesi): 155,077.00
# Organizzazione: Nansen International Office for Refugees
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for having carried on the work of Fridtjof Nansen to the benefit of refugees across Europe
# *************
# Anno: 1939
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 148,822.00
# *************
# Anno: 1940
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 138,570.00
# *************
# Anno: 1941
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 131,496.00
# *************
# Anno: 1942
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 131,891.00
# *************
# Anno: 1943
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 123,691.00
# *************
# Anno: 1944
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1945-11-12
# Motivazione: -
# Importo del premio (in corone svedesi): 121,841.00
# Organizzazione: International Committee of the Red Cross
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for the great work it has performed during the war on behalf of humanity
# *************
# Anno: 1945
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1945-11-12
# Motivazione: -
# Importo del premio (in corone svedesi): 121,333.00
# Persona: Cordell Hull
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his indefatigable work for international understanding and his pivotal role in establishing the United Nations
# *************
# Anno: 1946
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1946-11-14
# Motivazione: -
# Importo del premio (in corone svedesi): 121,524.00
# Persona: Emily Greene Balch
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for her lifelong work for the cause of peace
# Persona: John R. Mott
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his contribution to the creation of a peace-promoting religious brotherhood across national boundaries
# *************
# Anno: 1947
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1947-10-30
# Motivazione: -
# Importo del premio (in corone svedesi): 146,115.00
# Organizzazione: Friends Service Council
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their pioneering work in the international peace movement and compassionate effort to relieve human suffering, thereby promoting the fraternity between nations
# Organizzazione: American Friends Service Committee
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their pioneering work in the international peace movement and compassionate effort to relieve human suffering, thereby promoting the fraternity between nations
# *************
# Anno: 1948
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 159,773.00
# *************
# Anno: 1949
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1949-10-12
# Motivazione: -
# Importo del premio (in corone svedesi): 156,290.00
# Persona: Lord Boyd Orr
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his lifelong effort to conquer hunger and want, thereby helping to remove a major cause of military conflict and war
# *************
# Anno: 1950
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1950-09-22
# Motivazione: -
# Importo del premio (in corone svedesi): 164,304.00
# Persona: Ralph Bunche
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his work as mediator in Palestine in 1948-1949
# *************
# Anno: 1951
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: -
# Importo del premio (in corone svedesi): 167,612.00
# Persona: Léon Jouhaux
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for having devoted his life to the fight against war through the promotion of social justice and brotherhood among men and nations
# *************
# Anno: 1952
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1953-10-30
# Motivazione: -
# Importo del premio (in corone svedesi): 171,135.00
# Persona: Albert Schweitzer
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his altruism, reverence for life, and tireless humanitarian work which has helped making the idea of brotherhood between men and nations a living one
# *************
# Anno: 1953
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1953-10-30
# Motivazione: -
# Importo del premio (in corone svedesi): 175,293.00
# Persona: George C. Marshall
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for proposing and supervising the plan for the economic recovery of Europe
# *************
# Anno: 1954
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1955-11-05
# Motivazione: -
# Importo del premio (in corone svedesi): 181,647.00
# Organizzazione: Office of the United Nations High Commissioner for Refugees
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for its efforts to heal the wounds of war by providing help and protection to refugees all over the world
# *************
# Anno: 1955
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 190,214.00
# *************
# Anno: 1956
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 200,123.00
# *************
# Anno: 1957
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1957-10-03
# Motivazione: -
# Importo del premio (in corone svedesi): 208,629.00
# Persona: Lester Bowles Pearson
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his crucial contribution to the deployment of a United Nations Emergency Force in the wake of the Suez Crisis
# *************
# Anno: 1958
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1958-11-10
# Motivazione: -
# Importo del premio (in corone svedesi): 214,559.00
# Persona: Georges Pire
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his efforts to help refugees to leave their camps and return to a life of freedom and dignity
# *************
# Anno: 1959
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1959-11-05
# Motivazione: -
# Importo del premio (in corone svedesi): 220,678.00
# Persona: Philip Noel-Baker
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his longstanding contribution to the cause of disarmament and peace
# *************
# Anno: 1960
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1961-10-23
# Motivazione: -
# Importo del premio (in corone svedesi): 225,987.00
# Persona: Albert Lutuli
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his non-violent struggle against apartheid
# *************
# Anno: 1961
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1961-10-23
# Motivazione: -
# Importo del premio (in corone svedesi): 250,233.00
# Persona: Dag Hammarskjöld
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for developing the UN into an effective and constructive international organization, capable of giving life to the principles and aims expressed in the UN Charter
# *************
# Anno: 1962
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1963-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 257,220.00
# Persona: Linus Pauling
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his fight against the nuclear arms race between East and West
# *************
# Anno: 1963
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1963-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 265,000.00
# Organizzazione: International Committee of the Red Cross
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for promoting the principles of the Geneva Convention and cooperation with the UN
# Organizzazione: League of Red Cross Societies
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for promoting the principles of the Geneva Convention and cooperation with the UN
# *************
# Anno: 1964
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1964-10-14
# Motivazione: -
# Importo del premio (in corone svedesi): 273,000.00
# Persona: Martin Luther King Jr.
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his non-violent struggle for civil rights for the Afro-American population
# *************
# Anno: 1965
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1965-10-26
# Motivazione: -
# Importo del premio (in corone svedesi): 282,000.00
# Organizzazione: United Nations Children's Fund
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for its effort to enhance solidarity between nations and reduce the difference between rich and poor states
# *************
# Anno: 1966
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was allocated to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 300,000.00
# *************
# Anno: 1967
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money was with 1/3 allocated to the Main Fund and with 2/3 to the Special Fund of this prize section.
# Importo del premio (in corone svedesi): 320,000.00
# *************
# Anno: 1968
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1968-10-09
# Motivazione: -
# Importo del premio (in corone svedesi): 350,000.00
# Persona: René Cassin
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his struggle to ensure the rights of man as stipulated in the UN Declaration
# *************
# Anno: 1969
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1969-10-20
# Motivazione: -
# Importo del premio (in corone svedesi): 375,000.00
# Organizzazione: International Labour Organization
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for creating international legislation insuring certain norms for working conditions in every country
# *************
# Anno: 1970
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1970-10-21
# Motivazione: -
# Importo del premio (in corone svedesi): 400,000.00
# Persona: Norman Borlaug
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for having given a well-founded hope - the green revolution
# *************
# Anno: 1971
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1971-10-21
# Motivazione: -
# Importo del premio (in corone svedesi): 450,000.00
# Persona: Willy Brandt
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for paving the way for a meaningful dialogue between East and West
# *************
# Anno: 1972
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: -
# Motivazione: No Nobel Prize was awarded this year. The prize money for 1972 was allocated to the Main Fund.
# Importo del premio (in corone svedesi): 480,000.00
# *************
# Anno: 1973
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1973-10-17
# Motivazione: -
# Importo del premio (in corone svedesi): 510,000.00
# Persona: Henry Kissinger
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for jointly having negotiated a cease fire in Vietnam in 1973
# Persona: Le Duc Tho
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for jointly having negotiated a cease fire in Vietnam in 1973
# *************
# Anno: 1974
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1974-10-09
# Motivazione: -
# Importo del premio (in corone svedesi): 550,000.00
# Persona: Seán MacBride
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his efforts to secure and develop human rights throughout the world
# Persona: Eisaku Sato
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for his contribution to stabilize conditions in the Pacific rim area and for signing the Nuclear Non-Proliferation Treaty
# *************
# Anno: 1975
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1975-10-09
# Motivazione: -
# Importo del premio (in corone svedesi): 630,000.00
# Persona: Andrei Sakharov
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his struggle for human rights in the Soviet Union, for disarmament and cooperation between all nations
# *************
# Anno: 1976
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1977-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 681,000.00
# Persona: Betty Williams
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for the courageous efforts in founding a movement to put an end to the violent conflict in Northern Ireland
# Persona: Mairead Corrigan
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for the courageous efforts in founding a movement to put an end to the violent conflict in Northern Ireland
# *************
# Anno: 1977
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1977-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 700,000.00
# Organizzazione: Amnesty International
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for worldwide respect for human rights
# *************
# Anno: 1978
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1978-10-27
# Motivazione: -
# Importo del premio (in corone svedesi): 725,000.00
# Persona: Anwar al-Sadat
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for jointly having negotiated peace between Egypt and Israel in 1978
# Persona: Menachem Begin
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for jointly having negotiated peace between Egypt and Israel in 1978
# *************
# Anno: 1979
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1979-10-27
# Motivazione: -
# Importo del premio (in corone svedesi): 800,000.00
# Persona: Mother Teresa
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for her work for bringing help to suffering humanity
# *************
# Anno: 1980
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1980-10-27
# Motivazione: -
# Importo del premio (in corone svedesi): 880,000.00
# Persona: Adolfo Pérez Esquivel
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for being a source of inspiration to repressed people, especially in Latin America
# *************
# Anno: 1981
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1981-10-14
# Motivazione: -
# Importo del premio (in corone svedesi): 1,000,000.00
# Organizzazione: Office of the United Nations High Commissioner for Refugees
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for promoting the fundamental rights of refugees
# *************
# Anno: 1982
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1982-10-13
# Motivazione: -
# Importo del premio (in corone svedesi): 1,150,000.00
# Persona: Alva Myrdal
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for disarmament and nuclear and weapon-free zones
# Persona: Alfonso García Robles
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for disarmament and nuclear and weapon-free zones
# *************
# Anno: 1983
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1983-10-05
# Motivazione: -
# Importo del premio (in corone svedesi): 1,500,000.00
# Persona: Lech Walesa
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for non-violent struggle for free trade unions and human rights in Poland
# *************
# Anno: 1984
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1984-10-05
# Motivazione: -
# Importo del premio (in corone svedesi): 1,650,000.00
# Persona: Desmond Tutu
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his role as a unifying leader figure in the non-violent campaign to resolve the problem of apartheid in South Africa
# *************
# Anno: 1985
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1985-10-05
# Motivazione: -
# Importo del premio (in corone svedesi): 1,800,000.00
# Organizzazione: International Physicians for the Prevention of Nuclear War
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for spreading authoritative information and by creating awareness of the catastrophic consequences of nuclear war
# *************
# Anno: 1986
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1986-10-14
# Motivazione: -
# Importo del premio (in corone svedesi): 2,000,000.00
# Persona: Elie Wiesel
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for being a messenger to mankind: his message is one of peace, atonement and dignity
# *************
# Anno: 1987
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1987-10-13
# Motivazione: -
# Importo del premio (in corone svedesi): 2,175,000.00
# Persona: Oscar Arias Sánchez
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his work for lasting peace in Central America
# *************
# Anno: 1988
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1988-09-29
# Motivazione: -
# Importo del premio (in corone svedesi): 2,500,000.00
# Organizzazione: United Nations Peacekeeping Forces
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for preventing armed clashes and creating conditions for negotiations
# *************
# Anno: 1989
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1989-10-05
# Motivazione: -
# Importo del premio (in corone svedesi): 3,000,000.00
# Persona: The 14th Dalai Lama
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for advocating peaceful solutions based upon tolerance and mutual respect in order to preserve the historical and cultural heritage of his people
# *************
# Anno: 1990
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1990-10-15
# Motivazione: -
# Importo del premio (in corone svedesi): 4,000,000.00
# Persona: Mikhail Gorbachev
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for the leading role he played in the radical changes in East-West relations
# *************
# Anno: 1991
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1991-10-14
# Motivazione: -
# Importo del premio (in corone svedesi): 6,000,000.00
# Persona: Aung San Suu Kyi
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for her non-violent struggle for democracy and human rights
# *************
# Anno: 1992
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1992-10-16
# Motivazione: -
# Importo del premio (in corone svedesi): 6,500,000.00
# Persona: Rigoberta Menchú Tum
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for her struggle for social justice and ethno-cultural reconciliation based on respect for the rights of indigenous peoples
# *************
# Anno: 1993
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1993-10-15
# Motivazione: -
# Importo del premio (in corone svedesi): 6,700,000.00
# Persona: Nelson Mandela
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for the peaceful termination of the apartheid regime, and for laying the foundations for a new democratic South Africa
# Persona: F.W. de Klerk
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for the peaceful termination of the apartheid regime, and for laying the foundations for a new democratic South Africa
# *************
# Anno: 1994
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1994-10-14
# Motivazione: -
# Importo del premio (in corone svedesi): 7,000,000.00
# Persona: Yasser Arafat
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: for their efforts to create peace in the Middle East
# Persona: Shimon Peres
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: for their efforts to create peace in the Middle East
# Persona: Yitzhak Rabin
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: for their efforts to create peace in the Middle East
# *************
# Anno: 1995
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1995-10-13
# Motivazione: -
# Importo del premio (in corone svedesi): 7,200,000.00
# Persona: Joseph Rotblat
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to diminish the part played by nuclear arms in international politics and, in the longer run, to eliminate such arms
# Organizzazione: Pugwash Conferences on Science and World Affairs
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to diminish the part played by nuclear arms in international politics and, in the longer run, to eliminate such arms
# *************
# Anno: 1996
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1996-10-11
# Motivazione: -
# Importo del premio (in corone svedesi): 7,400,000.00
# Persona: Carlos Filipe Ximenes Belo
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work towards a just and peaceful solution to the conflict in East Timor
# Persona: José Ramos-Horta
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work towards a just and peaceful solution to the conflict in East Timor
# *************
# Anno: 1997
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1997-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 7,500,000.00
# Organizzazione: International Campaign to Ban Landmines
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for the banning and clearing of anti-personnel mines
# Persona: Jody Williams
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for the banning and clearing of anti-personnel mines
# *************
# Anno: 1998
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1998-10-16
# Motivazione: -
# Importo del premio (in corone svedesi): 7,600,000.00
# Persona: John Hume
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to find a peaceful solution to the conflict in Northern Ireland
# Persona: David Trimble
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to find a peaceful solution to the conflict in Northern Ireland
# *************
# Anno: 1999
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1999-10-15
# Motivazione: -
# Importo del premio (in corone svedesi): 7,900,000.00
# Organizzazione: Doctors Without Borders
# 	Porzione del Nobel vinta: 1
# 	Motivazione: in recognition of the organisation's pioneering humanitarian work on several continents
# *************
# Anno: 2000
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2000-10-13
# Motivazione: -
# Importo del premio (in corone svedesi): 9,000,000.00
# Persona: Kim Dae-jung
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his work for democracy and human rights in South Korea and in East Asia in general, and for peace and reconciliation with North Korea in particular
# *************
# Anno: 2001
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2001-10-12
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Organizzazione: United Nations
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for a better organized and more peaceful world
# Persona: Kofi Annan
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their work for a better organized and more peaceful world
# *************
# Anno: 2002
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2002-10-11
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Jimmy Carter
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his decades of untiring effort to find peaceful solutions to international conflicts, to advance democracy and human rights, and to promote economic and social development
# *************
# Anno: 2003
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2003-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Shirin Ebadi
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for her efforts for democracy and human rights. She has focused especially on the struggle for the rights of women and children
# *************
# Anno: 2004
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2004-10-08
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Wangari Maathai
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for her contribution to sustainable development, democracy and peace
# *************
# Anno: 2005
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2005-10-07
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Organizzazione: International Atomic Energy Agency
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to prevent nuclear energy from being used for military purposes and to ensure that nuclear energy for peaceful purposes is used in the safest possible way
# Persona: Mohamed ElBaradei
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to prevent nuclear energy from being used for military purposes and to ensure that nuclear energy for peaceful purposes is used in the safest possible way
# *************
# Anno: 2006
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2006-10-13
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Muhammad Yunus
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to create economic and social development from below
# Organizzazione: Grameen Bank
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to create economic and social development from below
# *************
# Anno: 2007
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2007-10-12
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Organizzazione: Intergovernmental Panel on Climate Change
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to build up and disseminate greater knowledge about man-made climate change, and to lay the foundations for the measures that are needed to counteract such change
# Persona: Al Gore
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to build up and disseminate greater knowledge about man-made climate change, and to lay the foundations for the measures that are needed to counteract such change
# *************
# Anno: 2008
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2008-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Martti Ahtisaari
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his important efforts, on several continents and over more than three decades, to resolve international conflicts
# *************
# Anno: 2009
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2009-10-09
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Barack H. Obama
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his extraordinary efforts to strengthen international diplomacy and cooperation between peoples
# *************
# Anno: 2010
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2010-10-08
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Liu Xiaobo
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his long and non-violent struggle for fundamental human rights in China
# *************
# Anno: 2011
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2011-10-07
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Ellen Johnson Sirleaf
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: for their non-violent struggle for the safety of women and for women's rights to full participation in peace-building work
# Persona: Leymah Gbowee
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: for their non-violent struggle for the safety of women and for women's rights to full participation in peace-building work
# Persona: Tawakkol Karman
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: for their non-violent struggle for the safety of women and for women's rights to full participation in peace-building work
# *************
# Anno: 2012
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2012-10-12
# Motivazione: -
# Importo del premio (in corone svedesi): 8,000,000.00
# Organizzazione: European Union
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for over six decades contributed to the advancement of peace and reconciliation, democracy and human rights in Europe
# *************
# Anno: 2013
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2013-10-11
# Motivazione: -
# Importo del premio (in corone svedesi): 8,000,000.00
# Organizzazione: Organisation for the Prohibition of Chemical Weapons
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for its extensive efforts to eliminate chemical weapons
# *************
# Anno: 2014
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2014-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 8,000,000.00
# Persona: Kailash Satyarthi
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their struggle against the suppression of children and young people and for the right of all children to education
# Persona: Malala Yousafzai
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their struggle against the suppression of children and young people and for the right of all children to education
# *************
# Anno: 2015
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2015-10-09
# Motivazione: -
# Importo del premio (in corone svedesi): 8,000,000.00
# Organizzazione: National Dialogue Quartet
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for its decisive contribution to the building of a pluralistic democracy in Tunisia in the wake of the Jasmine Revolution of 2011
# *************
# Anno: 2016
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2016-10-07
# Motivazione: -
# Importo del premio (in corone svedesi): 8,000,000.00
# Persona: Juan Manuel Santos
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his resolute efforts to bring the country's more than 50-year-long civil war to an end
# *************
# Anno: 2017
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2017-10-06
# Motivazione: -
# Importo del premio (in corone svedesi): 9,000,000.00
# Organizzazione: International Campaign to Abolish Nuclear Weapons
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for its work to draw attention to the catastrophic humanitarian consequences of any use of nuclear weapons and for its ground-breaking efforts to achieve a treaty-based prohibition of such weapons
# *************
# Anno: 2018
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2018-10-05
# Motivazione: -
# Importo del premio (in corone svedesi): 9,000,000.00
# Persona: Denis Mukwege
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to end the use of sexual violence as a weapon of war and armed conflict
# Persona: Nadia Murad
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to end the use of sexual violence as a weapon of war and armed conflict
# *************
# Anno: 2019
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2019-10-11
# Motivazione: -
# Importo del premio (in corone svedesi): 9,000,000.00
# Persona: Abiy Ahmed Ali
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for his efforts to achieve peace and international cooperation, and in particular for his decisive initiative to resolve the border conflict with neighbouring Eritrea
# *************
# Anno: 2020
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2020-10-09
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Organizzazione: World Food Programme
# 	Porzione del Nobel vinta: 1
# 	Motivazione: for its efforts to combat hunger, for its contribution to bettering conditions for peace in conflict-affected areas and for acting as a driving force in efforts to prevent the use of hunger as a weapon of war and conflict
# *************
# Anno: 2021
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2021-10-07
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Maria Ressa
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to safeguard freedom of expression, which is a precondition for democracy and lasting peace
# Persona: Dmitry Muratov
# 	Porzione del Nobel vinta: 1/2
# 	Motivazione: for their efforts to safeguard freedom of expression, which is a precondition for democracy and lasting peace
# *************
# Anno: 2022
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 2022-10-07
# Motivazione: -
# Importo del premio (in corone svedesi): 10,000,000.00
# Persona: Ales Bialiatski
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protect the fundamental rights of citizens. They have made an outstanding effort to document war crimes, human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy.
# Organizzazione: Memorial
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protect the fundamental rights of citizens. They have made an outstanding effort to document war crimes, human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy.
# Organizzazione: Center for Civil Liberties
# 	Porzione del Nobel vinta: 1/3
# 	Motivazione: The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protect the fundamental rights of citizens. They have made an outstanding effort to document war crimes, human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy.

# %% [markdown]
# #### 2. Cercare un Nobel (con data e anno)

# %%
print("Cercare un Nobel (con data e anno)")

# Richiesta degli input
anno = int(input("Inserire anno:"))
categoria = chiedi_categoria()
stampa_dettagli = input("Stampare anche i dettagli dei vincitori (y/n)?").lower()=='y'
print("Scelta: Anno: "+str(anno) +  "\tCategoria: " + categoria+ "\t"+("con" if stampa_dettagli else "senza" ) + " dettagli")

# Interrogazione e stampa dei risultati
if stampa_dettagli:
    lista_nobel = collection_nobelPrices2.aggregate([
        {'$match': {'awardYear':anno, "category":categoria}}, 
        LOOKUP_JOIN_COLLECTIONS
    ])
else:
    lista_nobel = collection_nobelPrices2.find({'awardYear':anno,"category":categoria}) 

print_nobels(lista_nobel, stampa_dettagli)
# Out:
# Cercare un Nobel (con data e anno)
# Inserire anno:2000
# Scegli una categoria tra:
# 0 -- Chemistry
# 1 -- Economic Sciences
# 2 -- Literature
# 3 -- Peace
# 4 -- Physics
# 5 -- Physiology or Medicine
# >> 0
# Stampare anche i dettagli dei vincitori (y/n)?y
# Scelta: Anno: 2000	Categoria: Chemistry	con dettagli
# *************
# Anno: 2000
# Categoria: Chemistry - anche detta The Nobel Prize in Chemistry
# Data: 2000-10-10
# Motivazione: -
# Importo del premio (in corone svedesi): 9,000,000.00
# Persona: Alan Heeger
# 	Altri nomi: Alan J. Heeger - Alan - Heeger
# 	Sesso: m
# 	Nato/a il 1936-01-22 a Sioux City, IA, USA
# 	Wikipedia: https://en.wikipedia.org/wiki/Alan_J._Heeger
# Persona: Alan MacDiarmid
# 	Altri nomi: Alan G. MacDiarmid - Alan - MacDiarmid
# 	Sesso: m
# 	Nato/a il 1927-04-14 a Masterton, New Zealand
# 	Morto/a il 2007-02-07 a Drexel Hill, PA, USA
# 	Wikipedia: https://en.wikipedia.org/wiki/Alan_MacDiarmid
# Persona: Hideki Shirakawa
# 	Altri nomi: Hideki Shirakawa - Hideki - Shirakawa
# 	Sesso: m
# 	Nato/a il 1936-08-20 a Tokyo, Japan
# 	Wikipedia: https://en.wikipedia.org/wiki/Hideki_Shirakawa

# %% [markdown]
# #### 3. Stampare i primi Nobel in ordine (crescente o decrescente) di importo o data

# %%
print("Stampare i primi N Nobel degli in ordine (crescente o decrescente) di importo o di data ")

# Richiesta degli input
n_str = input("Quanti nobel stampare (premere invio per stamparli tutti)?")
try:
    if n_str!="":
        n = int(n_str if n_str != "" else -1)
        if n<1:
            raise ValueError
    else:
        n = -1
except ValueError:
    print("Errore! Numero inserito non valido")
    raise MiaStopExecution

importo_o_data=""
while(not (importo_o_data=="1" or importo_o_data=="2")):
    importo_o_data = input("Si desiderano vedere i nobel in ordine di:\n1.Importo del premio\n2.Data\n>> ")
importo_o_data = "prizeAmount" if importo_o_data == "1" else "dateAwarded"

ordine=""
while(not (ordine=="1" or ordine=="2")):
    ordine = input("Si desiderano vedere i nobel in ordine:\n1.Crescente\n2.Decrescente\n>> ")
ordine = 1 if ordine == "1" else -1

stampa_dettagli = chiedi_stampa_dettagli()

print("Hai scelto: " + 
    ("tutti i nobel" if n==-1 else "primi " + n_str + " nobel" ) 
    + " in ordine " + ("crescente" if ordine == 1 else "decrescente") + " di "
    + ("data" if importo_o_data == "dateAwarded" else "importo") + " " 
    + ("con" if stampa_dettagli else "senza" ) + " dettagli"
)

# Interrogazione e stampa dei risultati
if stampa_dettagli:
    lista_filtri = [
        { '$match': {importo_o_data:{'$exists':'true'}}},    
        { '$sort':  {importo_o_data: ordine } },
        LOOKUP_JOIN_COLLECTIONS
    ]
    if n!=-1:
        lista_filtri += [{'$limit':n}]
    lista_nobel = collection_nobelPrices2.aggregate(lista_filtri)
else:
    lista_nobel = collection_nobelPrices2.find({importo_o_data:{'$exists':'true'}}).sort(importo_o_data, ordine)
    if n != -1:
        lista_nobel = lista_nobel.limit(n)

print_nobels(lista_nobel, stampa_dettagli)
# Out:
# Stampare i primi N Nobel degli in ordine (crescente o decrescente) di importo o di data
# Quanti nobel stampare (premere invio per stamparli tutti)?2
# Si desiderano vedere i nobel in ordine di:
# 1.Importo del premio
# 2.Data
# >> 2
# Si desiderano vedere i nobel in ordine:
# 1.Crescente
# 2.Decrescente
# >> 1
# Stampare anche i dettagli dei vincitori (y/n)?y
# Hai scelto: primi 2 nobel in ordine crescente di data con dettagli
# *************
# Anno: 1901
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1901-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 150,782.00
# Persona: Frédéric Passy
# 	Altri nomi: Frédéric Passy - Frédéric - Passy
# 	Sesso: m
# 	Nato/a il 1822-05-20 a Paris, France
# 	Morto/a il 1912-06-12 a Paris, France
# 	Wikipedia: https://en.wikipedia.org/wiki/Frédéric_Passy
# Persona: Henry Dunant
# 	Altri nomi: Jean Henry Dunant - Henry - Dunant
# 	Sesso: m
# 	Nato/a il 1828-05-08 a Geneva, Switzerland
# 	Morto/a il 1910-10-30 a Heiden, Switzerland
# 	Wikipedia: https://en.wikipedia.org/wiki/Henry_Dunant
# *************
# Anno: 1902
# Categoria: Peace - anche detta The Nobel Peace Prize
# Data: 1902-12-10
# Motivazione: -
# Importo del premio (in corone svedesi): 141,847.00
# Persona: Albert Gobat
# 	Altri nomi: Charles Albert Gobat - Albert - Gobat
# 	Sesso: m
# 	Nato/a il 1843-05-21 a Tramelan, Switzerland
# 	Morto/a il 1914-03-16 a Bern, Switzerland
# 	Wikipedia: https://en.wikipedia.org/wiki/Charles_Albert_Gobat
# Persona: Élie Ducommun
# 	Altri nomi: Élie Ducommun - Élie - Ducommun
# 	Sesso: m
# 	Nato/a il 1833-02-19 a Geneva, Switzerland
# 	Morto/a il 1906-12-07 a Bern, Switzerland
# 	Wikipedia: https://en.wikipedia.org/wiki/Élie_Ducommun

# %% [markdown]
# #### 4. Interrogazioni con max, min e avg

# %%
print("Interrogazioni con max, min e avg")
from math import trunc

# Interrogazione e stampa dei risultati
risultati = list(collection_nobelPrices2.aggregate([{ "$group": { 
        "_id": 'null',
        "max_data": { "$max": "$dateAwarded" } , 
        "min_data": { "$min": "$dateAwarded" } ,
        "max_prize": { "$max": "$prizeAmount" } , 
        "min_prize": { "$min": "$prizeAmount" } ,
        "avg_prize": { "$avg": "$prizeAmount"}
    }}]))[0]
print("I nobel presenti nel database:")
print("\t- sono stati vinti tra il " + risultati['min_data'] + " e il " + risultati["max_data"])
print("\t- hanno un importo compreso tra " + get_importo(risultati['min_prize']) + " e " + get_importo(risultati['max_prize']) + " (corone svedesi), per un importo medio di: " 
    + get_importo(risultati['avg_prize']))
# Out:
# Interrogazioni con max, min e avg
# I nobel presenti nel database:
# 	- sono stati vinti tra il 1901-12-10 e il 2022-10-07
# 	- hanno un importo compreso tra 114,935.00 e 10,000,000.00 (corone svedesi), per un importo medio di: 2,866,560.87

# %% [markdown]
# #### 5. Quanti Nobel sono stati vinti per ogni categoria?

# %%
print("Quanti Nobel sono stati vinti per ogni categoria?\n")
print("Categoria\t\t\tNumero di Nobel vinti")
print("--------------------------------------------------------")

category_count = list(collection_nobelPrices2.aggregate([   
    { '$match': {"laureates.id" : {'$exists': True}} },     # Nobel con un vincitore
    { '$unwind': "$category" },
    { '$group': { '_id': "$category" , 'count': { '$sum': 1 } }}, 
    { '$sort' : {'count':-1} }
]))

for elem in category_count:
    categoria = elem["_id"] 
    count = str(elem["count"])
    sep = "\t\t" if len(categoria)>16 else ("\t\t\t\t" if len(categoria)<9 else "\t\t\t")
    print(categoria +sep+ count)
# Out:
# Quanti Nobel sono stati vinti per ogni categoria?
#
# Categoria			Numero di Nobel vinti
# --------------------------------------------------------
# Physics				116
# Literature			115
# Chemistry			114
# Physiology or Medicine		113
# Peace				103
# Economic Sciences		54

# %% [markdown]
# #### 6. Persone/organizzazioni che hanno vinto piu di un Nobel

# %%
print("Persone/organizzazioni che hanno vinto piu di un Nobel")

# Richiesta degli input
print("Scegliere un'opzione:\n1. Considerare solo i vincitori che hanno vinto come singoli\n2. Considerare anche coloro che hanno vinto insieme ad altri vincitori")
opzione = ""
while (not(opzione=="1" or opzione=="2")):
    opzione = input(">> ")

stampa_dettagli = chiedi_stampa_dettagli()

# Interrogazione e stampa dei risultati
filtri_ricerca = [
    { '$group': { '_id': "$laureates.id" , 'count': { '$sum': 1 } }},
    { '$match' : {'count': {'$gt':1}}}, 
    { '$sort' : {'count':-1}},
    { '$lookup': { 
            "localField": "_id",
            "from": "laureates2",
            "foreignField": "id", 
            "as": "vincitore" 
        } 
    }
]
if opzione == "2":
    filtri_ricerca = [{ '$unwind': "$laureates" }] + filtri_ricerca

lista_vincitori = list(collection_nobelPrices2.aggregate(filtri_ricerca))

for elem in lista_vincitori:
    if len(elem["vincitore"]) == 0:
        continue
    print("--------------")
    print("Nobel vinti: " + str(elem["count"]))
    print_vincitore(elem["vincitore"][0], stampa_dettagli)
# Out:
# Persone/organizzazioni che hanno vinto piu di un Nobel
# Scegliere un'opzione:
# 1. Considerare solo i vincitori che hanno vinto come singoli
# 2. Considerare anche coloro che hanno vinto insieme ad altri vincitori
# >> 2
# Stampare anche i dettagli dei vincitori (y/n)?n
# --------------
# Nobel vinti: 3
# Organizzazione: International Committee of the Red Cross
# --------------
# Nobel vinti: 2
# Persona: K. Barry Sharpless
# --------------
# Nobel vinti: 2
# Persona: Frederick Sanger
# --------------
# Nobel vinti: 2
# Organizzazione: Office of the United Nations High Commissioner for Refugees
# --------------
# Nobel vinti: 2
# Persona: Marie Curie
# --------------
# Nobel vinti: 2
# Persona: John Bardeen
# --------------
# Nobel vinti: 2
# Persona: Linus Pauling

# %% [markdown]
# ### Interrogazioni con comandi non visti a lezione

# %% [markdown]
# #### 1. Stampare i dati di un vincitore random italiano

# %%
print("Stampare i dati di un vincitore random italiano")

vincitore_italiano = list(collection_laureates2.aggregate([
    {'$match': {"birth.place.countryNow":"Italy"}},     # Cerco tra i vincitori nati in Italia
    { '$sample': { 'size': 1 } }                        # Scelta di un documento in modo random
    ]))
    
for v in vincitore_italiano:
    print_vincitore(v, stampa_dettagli=True)
# Out:
# Stampare i dati di un vincitore random italiano
# Persona: Eugenio Montale
# 	Altri nomi: Eugenio Montale - Eugenio - Montale
# 	Sesso: m
# 	Nato/a il 1896-10-12 a Genoa, Italy
# 	Morto/a il 1981-09-12 a Milan, Italy
# 	Wikipedia: https://en.wikipedia.org/wiki/Eugenio_Montale

# %% [markdown]
# #### 2. Stampare gli anni in cui almeno una categoria non e' stata assegnata

# %%
print("Stampare gli anni in cui almeno una categoria non e' stata assegnata")

lista_nobel = list(collection_nobelPrices2.aggregate([
        { '$match': {"laureates.id" : {'$exists': False}} },            # Seleziono solo i nobel senza un vincitore
        { '$group': {
            "_id":'$awardYear',                                         # Raggruppo in base all'anno
            'categorie': {
                '$accumulator': {                                                           # Creo una funzione in JavaScript per concatenare le categorie: 
                    'accumulateArgs': ["$category"],                                        #   - Seleziono il field
                    'init': 'function() { return [] }',                                     #   - Inizializzo
                    'accumulate': 'function(stringa, s2) { return stringa.concat(s2) }',    #   - Unisco le due stringhe
                    'merge': 'function(s1, s2) { return s1.concat(s2) }',                   #   - Unisco le due stringhe
                    'finalize': 'function(stringa) { return stringa.join(", ") }',          #   - Metto una virgola tra le categorie
                    'lang': "js"
                 }
                 }
         }}, 
         { '$sort': {'_id':1}},                                         # Stampo in ordine di anno 
]))

for nobel in lista_nobel:
    print("Anno: " + str(nobel["_id"]) + "\tCategorie non assegnate: "+ nobel["categorie"])
# Out:
# Stampare gli anni in cui almeno una categoria non e' stata assegnata
# Anno: 1914	Categorie non assegnate: Literature, Peace
# Anno: 1915	Categorie non assegnate: Peace, Physiology or Medicine
# Anno: 1916	Categorie non assegnate: Chemistry, Peace, Physics, Physiology or Medicine
# Anno: 1917	Categorie non assegnate: Chemistry, Physiology or Medicine
# Anno: 1918	Categorie non assegnate: Literature, Peace, Physiology or Medicine
# Anno: 1919	Categorie non assegnate: Chemistry
# Anno: 1921	Categorie non assegnate: Physiology or Medicine
# Anno: 1923	Categorie non assegnate: Peace
# Anno: 1924	Categorie non assegnate: Chemistry, Peace
# Anno: 1925	Categorie non assegnate: Physiology or Medicine
# Anno: 1928	Categorie non assegnate: Peace
# Anno: 1931	Categorie non assegnate: Physics
# Anno: 1932	Categorie non assegnate: Peace
# Anno: 1933	Categorie non assegnate: Chemistry
# Anno: 1934	Categorie non assegnate: Physics
# Anno: 1935	Categorie non assegnate: Literature
# Anno: 1939	Categorie non assegnate: Peace
# Anno: 1940	Categorie non assegnate: Chemistry, Literature, Peace, Physics, Physiology or Medicine
# Anno: 1941	Categorie non assegnate: Chemistry, Literature, Peace, Physics, Physiology or Medicine
# Anno: 1942	Categorie non assegnate: Chemistry, Literature, Peace, Physics, Physiology or Medicine
# Anno: 1943	Categorie non assegnate: Literature, Peace
# Anno: 1948	Categorie non assegnate: Peace
# Anno: 1955	Categorie non assegnate: Peace
# Anno: 1956	Categorie non assegnate: Peace
# Anno: 1966	Categorie non assegnate: Peace
# Anno: 1967	Categorie non assegnate: Peace
# Anno: 1972	Categorie non assegnate: Peace

# %% [markdown]
# ### Scritture e modifiche

# %%
def chiedi_id_nome_vincitore():
    id = ""
    while id == "":
        name = input("Inserire il nome della persona/organizzazione: ")
        lista_ris = list(collection_laureates2.find({'$or': [{"knownName" : name}, {"orgName" : name}]} ))
        
        if len(lista_ris) ==0:
            print("Nessun risultato trovato. Reinserire il nome. ")
            continue

        print("Risultati trovati:")
        id_list = []
        for vincitore in lista_ris:
            print_vincitore(vincitore, True)
            if "id" in vincitore:
                print("\tid:" + vincitore["id"])                    
                id_list += [vincitore["id"]]
            print()
        id = input("Inserire il numero di id per confermare (premere invio per reinserire il nome): ")
        
        if id not in id_list:
            print("Id inserito non presente nella lista! Reinserire il nome. ")
            id = ""
            
    vincitore = list(collection_laureates2.find({'id':id}))[0]
    if "orgName" in vincitore:
        id_known_or_org_name = {"id": id, "orgName": vincitore["orgName"]}
    elif "knownName" in vincitore:
        id_known_or_org_name = {"id": id, "knownName": vincitore["knownName"]}
    return id_known_or_org_name

# %% [markdown]
# #### 1. Inserire un premio nobel ed eventualmente il vincitore

# %%
print("Inserire dati di un nuovo premio Nobel")
print("I dati non conosciuti possono essere omessi premendo invio")
from datetime import datetime

def check_data(data_str):
    """Questa funzione controlla che la data in input abbia un formato corretto"""
    if data_str != "":
        datetime.strptime(data_str, "%Y-%m-%d")

def inserisci_nuovo_vincitore():
    """Questa funzione inserisce nella collection un nuovo vincitore"""
    
    # Richiesta e controlli degli input relativi ai vincitori
    is_persona = input("Il nobel e' stato vinto da una persona (y/n)?") == 'y'
    if is_persona:
        knownName = input("Nome (principale): ")
        givenName = input("Altro nome: ")
        familyName = input("Nome della famiglia: ")
        fullName = input("Nome completo: ")
        gender = input("Sesso (m/f): ") 
        gender = "female" if gender == 'f' else "male"
        birthDate = input("Data di nascita ("+FORMATO_DATA+"): ")
        check_data(birthDate)
        birthPlace_cityNow = input("Citta di nascita: ")
        birthPlace_countryNow = input("Paese: ")

        deathDate = input("Data di morte ("+FORMATO_DATA+"): ")
        check_data(deathDate)
        deathPlace_cityNow = input("Citta di morte: ")
        deathPlace_countryNow = input("Paese: ")
    else:
        orgName = input("Nome (principale): ")
        nativeName = input("Altro nome: ")
        foundedDate = input("Data di fondazione ("+FORMATO_DATA+"): ")
        check_data(foundedDate)
        foundedPlace_cityNow = input("Citta di fondazione: ")
        foundedPlace_countryNow = input("Paese: ")

    wikipedia = input("Link alla pagina wikipedia: ")
    id = str(collection_laureates2.estimated_document_count()+1025)
    
    # Inserimento del documento e return 
    if is_persona:
        collection_laureates2.insert_one({
            "id" : id, 
            "knownName": knownName,
            "givenName": givenName,
            "familyName": familyName,
            "fullName": fullName,
            "gender": gender,
            "birth": {
                "date": birthDate,
                "place": {
                    "cityNow": birthPlace_cityNow,
                    "countryNow": birthPlace_countryNow
                }
            },
            "death": {
                "date": deathDate,
                "place": {
                    "cityNow": deathPlace_cityNow,
                    "countryNow": deathPlace_countryNow
                }
            },
            "wikipedia": wikipedia
        })
        return {"id" : id, "knownName": knownName }
    else: 
        collection_laureates2.insert_one({
            "id": id,
            "orgName": orgName,
            "nativeName": nativeName,
            "founded": {
                "date": foundedDate,
                "place": {
                    "cityNow": foundedPlace_cityNow,
                    "countryNow": foundedPlace_countryNow
                }
            },
            "wikipedia": wikipedia
        })
        return  {"id" : id, "orgName": orgName } 
    
        
# Richiesta dei valori relativi al premio Nobel
FORMATO_DATA = "aaaa-mm-gg"

awardYear = input("Anno: ")
awardYear = int(awardYear) if awardYear != "" else ""

category = input("Categoria: ")

categoryFullName = input("Nome completo della categoria: ")

dateAwarded = input("Data ("+FORMATO_DATA+"): ")
check_data(dateAwarded)

topMotivation = input("Motivazione: ")

prizeAmount = input("Importo (in corone svedesi): ")
prizeAmount = int(prizeAmount) if prizeAmount != "" else ""


n_laureates = int(input("Numero di vincitori: "))
lista_laureates = []

for i in range(n_laureates):
    # Richiesta dei dati dei vincitori
    print(f"---Dati del vincitore {i+1}---")
    giaPresente = input("Il vincitore e' gia presente (y/n) nel database? ") == 'y'
    if giaPresente:
        id_known_or_org_name = chiedi_id_nome_vincitore()
    else:
        id_known_or_org_name = inserisci_nuovo_vincitore()

    portion = input("Porzione del Nobel vinta (frazione): ")
    motivation = input("Motivazione: ")

    lista_laureates += [id_known_or_org_name|{"portion":portion, "motivation":motivation}]

# Inserimento del documento
inserted = collection_nobelPrices2.insert_one({
    "awardYear": awardYear,
    "category": category,
    "categoryFullName": categoryFullName,
    "dateAwarded": dateAwarded,
    "topMotivation": topMotivation,
    "prizeAmount": prizeAmount,
    "laureates": lista_laureates
})    

print("\nNobel memorizzato correttamente.")
# Out:
# Inserire dati di un nuovo premio Nobel
# I dati non conosciuti possono essere omessi premendo invio
# Anno: 2022
# Categoria: Peace
# Nome completo della categoria:
# Data (aaaa-mm-gg): 2022-10-10
# Motivazione: for peace
# Importo (in corone svedesi): 10000
# Numero di vincitori: 2
# ---Dati del vincitore 1---
# Il vincitore e' gia presente (y/n) nel database? y
# Inserire il nome della persona/organizzazione: Max Born
# Risultati trovati:
# Persona: Max Born
# 	Altri nomi: Max Born - Max - Born
# 	Sesso: m
# 	Nato/a il 1882-12-11 a Wroclaw, Poland
# 	Morto/a il 1970-01-05 a Göttingen, Germany
# 	Wikipedia: https://en.wikipedia.org/wiki/Max_Born
# 	id:61
#
# Inserire il numero di id per confermare (premere invio per reinserire il nome): 61
# Porzione del Nobel vinta (frazione): 1/2
# Motivazione: for peace 1
# ---Dati del vincitore 2---
# Il vincitore e' gia presente (y/n) nel database? n
# Il nobel e' stato vinto da una persona (y/n)?y
# Nome (principale): nome cognome
# Altro nome: abc
# Nome della famiglia: def
# Nome completo: ghi
# Sesso (m/f): f
# Data di nascita (aaaa-mm-gg): 2000-10-10
# Citta di nascita: Reggio Emilia
# Paese: Italy
# Data di morte (aaaa-mm-gg):
# Citta di morte:
# Paese:
# Link alla pagina wikipedia:
# Porzione del Nobel vinta (frazione): 1/2
# Motivazione: for peace 2
#
# Nobel memorizzato correttamente.

# %% [markdown]
# #### 2. Modifica dei dati di un vincitore

# %%
print("Modifica dei dati di un vincitore")

# Richiesta degli input
id_known_or_org_name = chiedi_id_nome_vincitore()
is_persona = "knownName" in id_known_or_org_name
if is_persona:
    lista_field = [ ("knownName", "Persona"), 
            ("fullName", "Altro nome 1:"), 
            ("givenName", "Altro nome 2"), 
            ("familyName", "Altro nome 3"), 
            ("gender", "Sesso (m/f)"), 
            ("birth.date", "Data di nascita"),
            ("birth.place.cityNow", "Citta di nascita"),
            ("birth.place.countryNow", "Paese di nascita"),
            ("death.date", "Data di morte"),
            ("death.place.cityNow", "Citta di morte"),
            ("death.place.countryNow", "Paese di morte"),
            ("wikipedia", "Link di wikipedia")
        ]
else:
    lista_field = [
        ("orgName", "Organizzazione"), 
        ("nativeName", "Altro Nome"), 
        ("founded.date", "Data di fondazione"),
        ("founded.place.cityNow", "Citta di fondazione"),
        ("founded.place.countryNow", "Paese di fondazione"),
        ("wikipedia", "Link di wikipedia")
    ]

print("Che valore si desidera aggiungere o modificare?")
for i in range(len(lista_field)):
    print(f"{i}. " + lista_field[i][1])
opzione = int(input(">> "))
if opzione < 0 or opzione >= len(lista_field):
    print("Valore non valido!")
    raise MiaStopExecution

nuovo_val = input("Inserire il nuovo valore: ")

if lista_field[opzione][0].__contains__("date"):
    check_data(nuovo_val) 
elif lista_field[opzione][0] == "gender":
    gender = "female" if nuovo_val == 'f' else "male"

# Modifico i dati
collection_laureates2.update_one({'id':id_known_or_org_name["id"]},{'$set':{lista_field[opzione][0]:nuovo_val}})
print("Documento memorizzato correttamente: ")
print_vincitore(list(collection_laureates2.find({'id':id_known_or_org_name["id"]}))[0], True)
# Out:
# Modifica dei dati di un vincitore
# Inserire il nome della persona/organizzazione: nome cognome
# Risultati trovati:
# Persona: nome cognome
# 	Altri nomi: ghi - abc - def
# 	Sesso: f
# 	Nato/a il 2000-10-10 a Reggio Emilia, Italy
# 	Morto/a il  a ,
# 	Wikipedia:
# 	id:2006
#
# Inserire il numero di id per confermare (premere invio per reinserire il nome): 2006
# Che valore si desidera aggiungere o modificare?
# 0. Persona
# 1. Altro nome 1:
# 2. Altro nome 2
# 3. Altro nome 3
# 4. Sesso (m/f)
# 5. Data di nascita
# 6. Citta di nascita
# 7. Paese di nascita
# 8. Data di morte
# 9. Citta di morte
# 10. Paese di morte
# 11. Link di wikipedia
# >> 8
# Inserire il nuovo valore: 2022-10-11
# Documento memorizzato correttamente:
# Persona: nome cognome
# 	Altri nomi: ghi - abc - def
# 	Sesso: f
# 	Nato/a il 2000-10-10 a Reggio Emilia, Italy
# 	Morto/a il 2022-10-11 a ,
# 	Wikipedia:
